# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.19.0'

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set/',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
cnn=tf.keras.models.Sequential()
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))
# Out:
# c:\Users\eshaa\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))
cnn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %%
cnn.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
cnn.fit(x=training_set,validation_data=test_set,epochs=25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 99ms/step - accuracy: 0.5425 - loss: 0.6953 - val_accuracy: 0.6380 - val_loss: 0.6378
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 90ms/step - accuracy: 0.6475 - loss: 0.6340 - val_accuracy: 0.7060 - val_loss: 0.5865
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 78ms/step - accuracy: 0.6813 - loss: 0.5922 - val_accuracy: 0.7265 - val_loss: 0.5421
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.7248 - loss: 0.5441 - val_accuracy: 0.6900 - val_loss: 0.5901
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 121ms/step - accuracy: 0.7413 - loss: 0.5119 - val_accuracy: 0.7520 - val_loss: 0.5094
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.7582 - loss: 0.4894 - val_accuracy: 0.7725 - val_loss: 0.4890
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.7695 - loss: 0.4670 - val_accuracy: 0.7875 - val_loss: 0.4681
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.7872 - loss: 0.4519 - val_accuracy: 0.7405 - val_loss: 0.5223
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 31s 125ms/step - accuracy: 0.7973 - loss: 0.4339 - val_accuracy: 0.7855 - val_loss: 0.4668
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 31s 123ms/step - accuracy: 0.7936 - loss: 0.4231 - val_accuracy: 0.7945 - val_loss: 0.4657
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 106ms/step - accuracy: 0.8023 - loss: 0.4151 - val_accuracy: 0.7880 - val_loss: 0.4976
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 76ms/step - accuracy: 0.8162 - loss: 0.3895 - val_accuracy: 0.8030 - val_loss: 0.4453
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.8279 - loss: 0.3767 - val_accuracy: 0.8065 - val_loss: 0.4622
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 75ms/step - accuracy: 0.8371 - loss: 0.3641 - val_accuracy: 0.8070 - val_loss: 0.4623
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 104ms/step - accuracy: 0.8555 - loss: 0.3329 - val_accuracy: 0.7985 - val_loss: 0.4634
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 139ms/step - accuracy: 0.8504 - loss: 0.3305 - val_accuracy: 0.7900 - val_loss: 0.4898
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 141ms/step - accuracy: 0.8620 - loss: 0.3276 - val_accuracy: 0.7645 - val_loss: 0.5734
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 34s 137ms/step - accuracy: 0.8695 - loss: 0.2949 - val_accuracy: 0.8005 - val_loss: 0.4988
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 104ms/step - accuracy: 0.8757 - loss: 0.2919 - val_accuracy: 0.8010 - val_loss: 0.5054
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.8922 - loss: 0.2519 - val_accuracy: 0.8045 - val_loss: 0.4959
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 78ms/step - accuracy: 0.8900 - loss: 0.2580 - val_accuracy: 0.8040 - val_loss: 0.5146
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 78ms/step - accuracy: 0.8975 - loss: 0.2525 - val_accuracy: 0.7980 - val_loss: 0.5103
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.9099 - loss: 0.2166 - val_accuracy: 0.8040 - val_loss: 0.5451
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 92ms/step - accuracy: 0.9140 - loss: 0.2159 - val_accuracy: 0.7880 - val_loss: 0.5777
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.9193 - loss: 0.2010 - val_accuracy: 0.8055 - val_loss: 0.5731

# %%
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt
img_path='cat.jpeg'
img=image.load_img(img_path,target_size=(64,64))
pic=img
img=image.img_to_array(img)
img=np.expand_dims(img,axis=0)
result=cnn.predict(img)
if result[0][0]==1:
    print('Doggy')
else:
    print('Kitty')
plt.imshow(image.load_img(img_path))
plt.axis('off')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Kitty
# (-0.5, 2559.5, 1919.5, -0.5)

# %%
img_path='dog.jpeg'
img=image.load_img(img_path,target_size=(64,64))
pic=img
img=image.img_to_array(img)
img=np.expand_dims(img,axis=0)
result=cnn.predict(img)
if result[0][0]==1:
    print('Doggy')
else:
    print('Kitty')
plt.imshow(image.load_img(img_path))
plt.axis('off')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Doggy
# (-0.5, 5256.5, 3504.5, -0.5)
